# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Graph

# %%
x= [1,2,4,5,6,8]
y= [2,5,7,9,11,13]

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,marker='o')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.title("Graph")
plt.show()
